# %%
import requests

# https://earthquake.usgs.gov/fdsnws/event/1/  -- USGS earthquake data
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query'

params = {
    'format': 'geojson',
    'starttime': '2024-01-01',
    'endtime': '2024-01-31',
    'minmagnitude': 5
}

response = requests.get(url, params=params)
data = response.json()

# %%
# data  # uncomment to see the full data, records that we want are in data['features']

# %%
# Pretty-print first record with correct JSON syntax
import json

sample = data['features'][0]
print(json.dumps(sample, indent=2))  # ← converts to valid JSON, so that we can use it in other json tools
# Out:
# {
#   "type": "Feature",
#   "properties": {
#     "mag": 5,
#     "place": "157 km NW of Ternate, Indonesia",
#     "time": 1706637927752,
#     "updated": 1713036506040,
#     "tz": null,
#     "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000lv28",
#     "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000lv28&format=geojson",
#     "felt": null,
#     "cdi": null,
#     "mmi": null,
#     "alert": null,
#     "status": "reviewed",
#     "tsunami": 0,
#     "sig": 385,
#     "net": "us",
#     "code": "7000lv28",
#     "ids": ",us7000lv28,",
#     "sources": ",us,",
#     "types": ",origin,phase-data,",
#     "nst": 112,
#     "dmin": 1.419,
#     "rms": 0.71,
#     "gap": 54,
#     "magType": "mb",
#     "type": "earthquake",
#     "title": "M 5.0 - 157 km NW of Ternate, Indonesia"
#   },
#   "geometry": {
#     "type": "Point",
#     "coordinates": [
#       126.4795,
#       1.8874,
#       41.461
#     ]
#   },
#   "id": "us7000lv28"
# }

# %% [markdown]
# ## Data Dictionary
# Official description copied from this [link](https://earthquake.usgs.gov/data/comcat/data-eventterms.php).
#
#
# | Column  | Data Type    | Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |---------|--------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | mag     | Decimal      | The magnitude for the event.                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | place   | String       | Textual description of named geographic region near to the event. This may be a city name, or a Flinn-Engdahl Region name.                                                                                                                                                                                                                                                                                                                                                       |
# | time    | Long Integer | Time when the event occurred. Times are reported in milliseconds since the epoch ( `1970-01-01T00:00:00.000Z`), and do not include leap seconds. In certain output formats, the date is formatted for readability.                                                                                                                                                                                                                                                                 |
# | updated | Long Integer | Time when the event was most recently updated. Times are reported in milliseconds since the <abbr title="January 1,1970">epoch</abbr>. In certain output formats, the date is formatted for readability.                                                                                                                                                                                                                                                                                                             |
# | tz      | Integer      | Timezone offset from UTC in minutes at the event epicenter.                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | url     | String       | Link to USGS Event Page for event.                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | detail  | String       | Link to [GeoJSON detail](https://earthquake.usgs.gov/earthquakes/feed/v1.0/geojson_detail.php) feed from a [GeoJSON summary](https://earthquake.usgs.gov/earthquakes/feed/v1.0/geojson.php) feed. <br>NOTE: When searching and using geojson with callback, no callback is included in the `detail` url.                                                                                                                                                                                                                                                                                                                        |
# | felt    | Integer      | The total number of felt reports submitted to the [DYFI?](https://earthquake.usgs.gov/data/dyfi/) system.                                                                                                                                                                                                                                                                                                                                                                                                                  |
# | cdi     | Decimal      | The maximum reported intensity (community determined intensity) for the event. Computed by [DYFI](https://earthquake.usgs.gov/data/dyfi/). While typically reported as a roman numeral, for the purposes of this API, intensity is expected as the decimal equivalent of the roman numeral. Learn more about [magnitude vs. intensity](https://www.usgs.gov/programs/earthquake-hazards/earthquake-magnitude-energy-release-and-shaking-intensity).                                                                                                                                                                                                                       |
# | mmi     | Decimal      | The maximum estimated instrumental intensity (modified/measured Mercalli intensity) for the event. Computed by [ShakeMap](https://earthquake.usgs.gov/data/shakemap/). While typically reported as a roman numeral, for the purposes of this API, intensity is expected as the decimal equivalent of the roman numeral. Learn more about [magnitude vs. intensity](https://www.usgs.gov/programs/earthquake-hazards/earthquake-magnitude-energy-release-and-shaking-intensity).                                                                                                                                                                                                     |
# | alert   | String       | The alert level from the [PAGER earthquake impact scale](https://earthquake.usgs.gov/data/pager/).                                                                                                                                                                                                                                                                                                                                                                                                                          |
# | status  | String       | Indicates whether the event has been reviewed by a human.                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | tsunami | Integer      | This flag is set to "1" for large events in oceanic regions and "0" otherwise. **The existence or value of this flag does not indicate if a tsunami actually did or will exist.** If the flag value is "1", the event will include a link to the NOAA Tsunami website for tsunami information. The USGS is not responsible for Tsunami warning; we are simply providing a link to the authoritative NOAA source. See http://www.tsunami.gov/ for all current tsunami alert statuses. |
# | sig     | Integer      | A number describing how significant the event is. Larger numbers indicate a more significant event. This value is determined on a number of factors, including: magnitude, maximum MMI, felt reports, and estimated impact.                                                                                                                                                                                                                                                      |
# | net     | String       | The network ID of a data contributor. Identifies the network considered to be the preferred source of information for this event.                                                                                                                                                                                                                                                                                                                                                        |
# | code    | String       | An identifying code assigned by - and unique from - the [corresponding source](https://earthquake.usgs.gov/data/comcat/index.php#net) for the event.                                                                                                                                                                                                                                                                                                                                                                                      |
# | ids     | String       | A comma-separated list of [event ids](https://earthquake.usgs.gov/data/comcat/index.php#id) that are associated to an event.                                                                                                                                                                                                                                                                                                                                                                                                             |
# | sources | String       | A comma-separated list of [network contributors](https://earthquake.usgs.gov/data/comcat/index.php#net).                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# | types   | String       | A comma-separated list of product types associated to this event.                                                                                                                                                                                                                                                                                                                                                                                                                |
# | nst     | Integer      | The total number of seismic stations used to determine earthquake location.                                                                                                                                                                                                                                                                                                                                                                                                      |
# | dmin    | Decimal      | Horizontal distance from the epicenter to the nearest station (in degrees). 1 degree is approximately 111.2 kilometers. In general, the smaller this number, the more reliable is the calculated depth of the earthquake.                                                                                                                                                                                                                                                        |
# | rms     | Decimal      | The root-mean-square (RMS) travel time residual, in sec, using all weights. This parameter provides a measure of the fit of the observed arrival times to the predicted arrival times for this location. Smaller numbers reflect a better fit of the data. The value is dependent on the accuracy of the velocity model used to compute the earthquake location, the quality weights assigned to the arrival time data, and the procedure used to locate the earthquake.         |
# | gap     | Decimal      | The largest azimuthal gap between azimuthally adjacent stations (in degrees). In general, the smaller this number, the more reliable is the calculated horizontal position of the earthquake. Earthquake locations in which the azimuthal gap exceeds 180 degrees typically have large location and depth uncertainties.                                                                                                                                                         |
# | magType | String       | The method or algorithm used to calculate the preferred magnitude for the event.                                                                                                                                                                                                                                                                                                                                                                                                 |
# | type    | String       | Type of seismic event.                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# | title   | String       | A short name of the record.                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | id      | String       | A unique identifier for the event. This is the current preferred id for the event, and may change over time. [See the "ids" GeoJSON format property.](https://earthquake.usgs.gov/data/comcat/index.php#ids)                                                                                                                                                                                                                                                                                                                              |

# %%
# download script written by ChatGPT

import requests
import json
import time
from calendar import monthrange

def fetch_monthly_data(year, month, min_mag=2.0, out_dir="data"):
    start = f"{year}-{month:02d}-01"
    end_day = monthrange(year, month)[1]
    end = f"{year}-{month:02d}-{end_day}"
    
    url = "https://earthquake.usgs.gov/fdsnws/event/1/query"
    params = {
        "format": "geojson",
        "starttime": start,
        "endtime": end,
        "minmagnitude": min_mag,
        "limit": 20000,
        "orderby": "time"
    }

    print(f"Fetching {start} to {end}...")
    r = requests.get(url, params=params)
    
    if r.ok:
        data = r.json()
        filename = f"{out_dir}/quakes_{year}_{month:02d}.json"
        with open(filename, "w") as f:
            json.dump(data, f)
        print(f"{year}-{month:02d}: {len(data['features'])} records")
        return len(data['features'])
    else:
        print(f"Error {r.status_code} for {year}-{month:02d}")
        return 0

total = 0
for year in range(1990, 2025):
    for month in range(1, 13):
        total += fetch_monthly_data(year, month)
        time.sleep(0.5)

print("✅ Total records:", total)
# Out:
# Fetching 1990-01-01 to 1990-01-31...
# 1990-01: 1411 records
# Fetching 1990-02-01 to 1990-02-28...
# 1990-02: 1362 records
# Fetching 1990-03-01 to 1990-03-31...
# 1990-03: 1908 records
# Fetching 1990-04-01 to 1990-04-30...
# 1990-04: 1875 records
# Fetching 1990-05-01 to 1990-05-31...
# 1990-05: 1473 records
# Fetching 1990-06-01 to 1990-06-30...
# 1990-06: 1290 records
# Fetching 1990-07-01 to 1990-07-31...
# 1990-07: 1478 records
# Fetching 1990-08-01 to 1990-08-31...
# 1990-08: 1453 records
# Fetching 1990-09-01 to 1990-09-30...
# 1990-09: 1300 records
# Fetching 1990-10-01 to 1990-10-31...
# 1990-10: 1464 records
# Fetching 1990-11-01 to 1990-11-30...
# 1990-11: 1443 records
# Fetching 1990-12-01 to 1990-12-31...
# 1990-12: 1546 records
# Fetching 1991-01-01 to 1991-01-31...
# 1991-01: 1703 records
# Fetching 1991-02-01 to 1991-02-28...
# 1991-02: 1427 records
# Fetching 1991-03-01 to 1991-03-31...
# 1991-03: 1667 records
# Fetching 1991-04-01 to 1991-04-30...
# 1991-04: 1585 records
# Fetching 1991-05-01 to 1991-05-31...
# 1991-05: 1537 records
# Fetching 1991-06-01 to 1991-06-30...
# 1991-06: 1565 records
# Fetching 1991-07-01 to 1991-07-31...
# 1991-07: 1469 records
# Fetching 1991-08-01 to 1991-08-31...
# 1991-08: 1615 records
# Fetching 1991-09-01 to 1991-09-30...
# 1991-09: 1353 records
# Fetching 1991-10-01 to 1991-10-31...
# 1991-10: 1577 records
# Fetching 1991-11-01 to 1991-11-30...
# 1991-11: 1418 records
# Fetching 1991-12-01 to 1991-12-31...
# 1991-12: 1708 records
# Fetching 1992-01-01 to 1992-01-31...
# 1992-01: 1490 records
# Fetching 1992-02-01 to 1992-02-29...
# 1992-02: 1503 records
# Fetching 1992-03-01 to 1992-03-31...
# 1992-03: 1662 records
# Fetching 1992-04-01 to 1992-04-30...
# 1992-04: 3938 records
# Fetching 1992-05-01 to 1992-05-31...
# 1992-05: 2794 records
# Fetching 1992-06-01 to 1992-06-30...
# 1992-06: 2931 records
# Fetching 1992-07-01 to 1992-07-31...
# 1992-07: 8345 records
# Fetching 1992-08-01 to 1992-08-31...
# 1992-08: 3519 records
# Fetching 1992-09-01 to 1992-09-30...
# 2010-10: 2509 records
# Fetching 2010-11-01 to 2010-11-30...
# 2010-11: 2544 records
# Fetching 2010-12-01 to 2010-12-31...
# 2010-12: 3040 records
# Fetching 2011-01-01 to 2011-01-31...
# 2011-01: 2372 records
# Fetching 2011-02-01 to 2011-02-28...
# 2011-02: 2148 records
# Fetching 2011-03-01 to 2011-03-31...
# 2011-03: 4941 records
# Fetching 2011-04-01 to 2011-04-30...
# 2011-04: 2762 records
# Fetching 2011-05-01 to 2011-05-31...
# 2011-05: 2506 records
# Fetching 2011-06-01 to 2011-06-30...
# 2011-06: 2182 records
# Fetching 2011-07-01 to 2011-07-31...
# 2011-07: 2611 records
# Fetching 2011-08-01 to 2011-08-31...
# 2011-08: 2332 records
# Fetching 2011-09-01 to 2011-09-30...
# 2011-09: 2153 records
# Fetching 2011-10-01 to 2011-10-31...
# 2011-10: 2128 records
# Fetching 2011-11-01 to 2011-11-30...
# 2011-11: 2163 records
# Fetching 2011-12-01 to 2011-12-31...
# 2011-12: 1905 records
# Fetching 2012-01-01 to 2012-01-31...
# 2012-01: 2031 records
# Fetching 2012-02-01 to 2012-02-29...
# 2012-02: 2050 records
# Fetching 2012-03-01 to 2012-03-31...
# 2012-03: 2084 records
# Fetching 2012-04-01 to 2012-04-30...
# 2012-04: 2427 records
# Fetching 2012-05-01 to 2012-05-31...
# 2012-05: 2067 records
# Fetching 2012-06-01 to 2012-06-30...
# 2012-06: 1887 records
# Fetching 2012-07-01 to 2012-07-31...
# 2012-07: 1962 records
# Fetching 2012-08-01 to 2012-08-31...
# 2012-08: 2485 records
# Fetching 2012-09-01 to 2012-09-30...
# 2012-09: 2876 records
# Fetching 2012-10-01 to 2012-10-31...
# 2012-10: 2500 records
# Fetching 2012-11-01 to 2012-11-30...
# 2012-11: 2187 records
# Fetching 2012-12-01 to 2012-12-31...
# 2012-12: 2126 records
# Fetching 2013-01-01 to 2013-01-31...
# 2013-01: 2369 records
# Fetching 2013-02-01 to 2013-02-28...
# 2013-02: 2470 records
# Fetching 2013-03-01 to 2013-03-31...
# 2013-03: 1936 records
# Fetching 2013-04-01 to 2013-04-30...
# 2013-04: 2129 records
# Fetching 2013-05-01 to 2013-05-31...
# 2013-05: 2544 records
# Fetching 2013-06-01 to 2013-06-30...
# 2013-06: 2008 records
# Fetching 2013-07-01 to 2013-07-31...
# 2013-07: 2120 records
# Fetching 2013-08-01 to 2013-08-31...
# 2013-08: 2183 records
# Fetching 2013-09-01 to 2013-09-30...
# 2013-09: 2361 records
# Fetching 2013-10-01 to 2013-10-31...
# 2013-10: 2245 records
# Fetching 2013-11-01 to 2013-11-30...
# 2013-11: 2701 records
# Fetching 2013-12-01 to 2013-12-31...
# 2013-12: 2451 records
# Fetching 2014-01-01 to 2014-01-31...
# 2014-01: 3055 records
# Fetching 2014-02-01 to 2014-02-28...
# 2014-02: 2396 records
# Fetching 2014-03-01 to 2014-03-31...
# 2014-03: 3014 records
# Fetching 2014-04-01 to 2014-04-30...
# 2014-04: 3541 records
# Fetching 2014-05-01 to 2014-05-31...
# 2014-05: 2895 records
# 2018-01: 3589 records
# Fetching 2018-02-01 to 2018-02-28...
# 2018-02: 3236 records
# Fetching 2018-03-01 to 2018-03-31...
# 2018-03: 3016 records
# Fetching 2018-04-01 to 2018-04-30...
# 2018-04: 2804 records
# Fetching 2018-05-01 to 2018-05-31...
# 2018-05: 5231 records
# Fetching 2018-06-01 to 2018-06-30...
# 2018-06: 13225 records
# Fetching 2018-07-01 to 2018-07-31...
# 2018-07: 16490 records
# Fetching 2018-08-01 to 2018-08-31...
# 2018-08: 6360 records
# Fetching 2018-09-01 to 2018-09-30...
# 2018-09: 3429 records
# Fetching 2018-10-01 to 2018-10-31...
# 2018-10: 3326 records
# Fetching 2018-11-01 to 2018-11-30...
# 2018-11: 2672 records
# Fetching 2018-12-01 to 2018-12-31...
# 2018-12: 4498 records
# Fetching 2019-01-01 to 2019-01-31...
# 2019-01: 2910 records
# Fetching 2019-02-01 to 2019-02-28...
# 2019-02: 2626 records
# Fetching 2019-03-01 to 2019-03-31...
# 2019-03: 3054 records
# Fetching 2019-04-01 to 2019-04-30...
# 2019-04: 2806 records
# Fetching 2019-05-01 to 2019-05-31...
# 2019-05: 2563 records
# Fetching 2019-06-01 to 2019-06-30...
# 2019-06: 2670 records
# Fetching 2019-07-01 to 2019-07-31...
# 2019-07: 8363 records
# Fetching 2019-08-01 to 2019-08-31...
# 2019-08: 2941 records
# Fetching 2019-09-01 to 2019-09-30...
# 2019-09: 3097 records
# Fetching 2019-10-01 to 2019-10-31...
# 2019-10: 3073 records
# Fetching 2019-11-01 to 2019-11-30...
# 2019-11: 3018 records
# Fetching 2019-12-01 to 2019-12-31...
# 2019-12: 3404 records
# Fetching 2020-01-01 to 2020-01-31...
# 2020-01: 6722 records
# Fetching 2020-02-01 to 2020-02-29...
# 2020-02: 3527 records
# Fetching 2020-03-01 to 2020-03-31...
# 2020-03: 3556 records
# Fetching 2020-04-01 to 2020-04-30...
# 2020-04: 3997 records
# Fetching 2020-05-01 to 2020-05-31...
# 2020-05: 5264 records
# Fetching 2020-06-01 to 2020-06-30...
# 2020-06: 4018 records
# Fetching 2020-07-01 to 2020-07-31...
# 2020-07: 4218 records
# Fetching 2020-08-01 to 2020-08-31...
# 2020-08: 3557 records
# Fetching 2020-09-01 to 2020-09-30...
# 2020-09: 2996 records
# Fetching 2020-10-01 to 2020-10-31...
# 2020-10: 4550 records
# Fetching 2020-11-01 to 2020-11-30...
# 2020-11: 3803 records
# Fetching 2020-12-01 to 2020-12-31...
# 2020-12: 4038 records
# Fetching 2021-01-01 to 2021-01-31...
# 2021-01: 4561 records
# Fetching 2021-02-01 to 2021-02-28...
# 2021-02: 3520 records
# Fetching 2021-03-01 to 2021-03-31...
# 2021-03: 4221 records
# Fetching 2021-04-01 to 2021-04-30...
# 2021-04: 3274 records
# Fetching 2021-05-01 to 2021-05-31...
# 2021-05: 3043 records
# Fetching 2021-06-01 to 2021-06-30...
# 2021-06: 3339 records
# Fetching 2021-07-01 to 2021-07-31...
# 2021-07: 4285 records
# Fetching 2021-08-01 to 2021-08-31...
# 2021-08: 4918 records
1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024
# mv quakes_1990_*.json 1990
# mv quakes_1991_*.json 1991
# mv quakes_1992_*.json 1992
# mv quakes_1993_*.json 1993
# mv quakes_1994_*.json 1994
# mv quakes_1995_*.json 1995
# mv quakes_1996_*.json 1996
# mv quakes_1997_*.json 1997
# mv quakes_1998_*.json 1998
# mv quakes_1999_*.json 1999
# mv quakes_2000_*.json 2000
# mv quakes_2001_*.json 2001
# mv quakes_2002_*.json 2002
# mv quakes_2003_*.json 2003
# mv quakes_2004_*.json 2004
# mv quakes_2005_*.json 2005
# mv quakes_2006_*.json 2006
# mv quakes_2007_*.json 2007
# mv quakes_2008_*.json 2008
# mv quakes_2009_*.json 2009
# mv quakes_2010_*.json 2010
# mv quakes_2011_*.json 2011
# mv quakes_2012_*.json 2012
# mv quakes_2013_*.json 2013
# mv quakes_2014_*.json 2014
# mv quakes_2015_*.json 2015
# mv quakes_2016_*.json 2016
# mv quakes_2017_*.json 2017
# mv quakes_2018_*.json 2018
# mv quakes_2019_*.json 2019
# mv quakes_2020_*.json 2020
# mv quakes_2021_*.json 2021
# mv quakes_2022_*.json 2022
# mv quakes_2023_*.json 2023
# mv quakes_2024_*.json 2024
# ```
# ```powershell
# # powershell
# gcloud auth activate-service-account --key-file=.gcp/key.json   <!-- use your own gcp key file -->
# gcloud config set project your-project-id
# cd ..
# gsutil -m cp -r data/* gs://your-bucket-name/raw/
# ```

# %%
# print and test with one file to see the pandas table
import pandas as pd

json_file = 'data/raw/1990/quakes_1990_01.json'

with open(json_file, "r") as f:
    data = json.load(f)

# Normalize GeoJSON structure
df = pd.json_normalize(data['features'])  # rmb the data we need is only in the ['features'] part
df.head(2)
# Out:
#       type          id  properties.mag  \
# 0  Feature  usp00044wv            2.00
# 1  Feature    nc151571            2.76
#
#                                     properties.place  properties.time  \
# 0  101 km ENE of Olonkinbyen, Svalbard and Jan Mayen     633740373610
# 1          14 km E of Hidden Valley Lake, California     633740271500
#
#    properties.updated properties.tz  \
# 0       1415321136135          None
# 1       1481921089681          None
#
#                                       properties.url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                    properties.detail properties.felt  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...            None  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...            None  ...
#
#                     properties.types  properties.nst properties.dmin  \
# 0                ,origin,phase-data,             NaN             NaN
# 1  ,nearby-cities,origin,phase-data,             9.0         0.04685
#
#   properties.rms  properties.gap  properties.magType properties.type  \
# 0           0.10             NaN                  md      earthquake
# 1           0.03           141.0                  md    quarry blast
#
#                                     properties.title geometry.type  \
# 0  M 2.0 - 101 km ENE of Olonkinbyen, Svalbard an...         Point
# 1  M 2.8 Quarry Blast - 14 km E of Hidden Valley ...         Point
#
#                  geometry.coordinates
# 0                [-6.012, 71.134, 10]
# 1  [-122.3938333, 38.8268333, -0.436]
#
# [2 rows x 30 columns]

# %%
# Extract coordinates
df["longitude"] = df["geometry.coordinates"].apply(lambda x: x[0])
df["latitude"] = df["geometry.coordinates"].apply(lambda x: x[1])
df["depth_km"] = df["geometry.coordinates"].apply(lambda x: x[2])

# Rename conflicting columns
df = df.rename(columns={
    "type": "record_type",                 # root
    "properties.type": "event_type",       # properties
    "geometry.type": "geometry_type"       # geometry
})

# Rename for clarity
df.columns = [col.split(".")[-1] for col in df.columns]

df.head(2)
# Out:
#   record_type          id   mag  \
# 0     Feature  usp00044wv  2.00
# 1     Feature    nc151571  2.76
#
#                                                place          time  \
# 0  101 km ENE of Olonkinbyen, Svalbard and Jan Mayen  633740373610
# 1          14 km E of Hidden Valley Lake, California  633740271500
#
#          updated    tz                                                url  \
# 0  1415321136135  None  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  1481921089681  None  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail  felt  ...   rms    gap  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...  None  ...  0.10    NaN
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...  None  ...  0.03  141.0
#
#   magType    event_type                                              title  \
# 0      md    earthquake  M 2.0 - 101 km ENE of Olonkinbyen, Svalbard an...
# 1      md  quarry blast  M 2.8 Quarry Blast - 14 km E of Hidden Valley ...
#
#    geometry_type                         coordinates   longitude   latitude  \
# 0          Point                [-6.012, 71.134, 10]   -6.012000  71.134000
# 1          Point  [-122.3938333, 38.8268333, -0.436] -122.393833  38.826833
#
#   depth_km
# 0   10.000
# 1   -0.436
#
# [2 rows x 33 columns]

# %%
# convert the json into parquet

import json
import pandas as pd
import pathlib

input_dir = pathlib.Path("data/raw")  # or path to your JSONs
output_dir = pathlib.Path("data/parquet")
output_dir.mkdir(exist_ok=True)   # exist_ok means ignore error if folder already exist

for json_file in input_dir.rglob("*.json"):  # glob -- global pattern matching, r mean recursive
    with open(json_file, "r") as f:
        data = json.load(f)
    
    # Normalize GeoJSON structure
    df = pd.json_normalize(data['features'])

    # Extract coordinates
    df["longitude"] = df["geometry.coordinates"].apply(lambda x: x[0])
    df["latitude"] = df["geometry.coordinates"].apply(lambda x: x[1])
    df["depth_km"] = df["geometry.coordinates"].apply(lambda x: x[2])

    # Rename conflicting columns
    df = df.rename(columns={
        "type": "record_type",                 # root
        "properties.type": "event_type",       # properties
        "geometry.type": "geometry_type"       # geometry
    })

    # Rename for clarity
    df.columns = [col.split(".")[-1] for col in df.columns]

    # hit some datatype error in bigquery so need to make sure columns are correctly casted
    columns_float = ['mag', 'cdi', 'mmi', 'dmin', 'rms', 'gap', 'longitude', 'latitude', 'depth_km']
    columns_int = ['time', 'updated', 'tz', 'felt', 'tsunami', 'sig', 'nst']

    for col in columns_float:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce').astype(float)

    for col in columns_int:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce').astype(pd.Int64Dtype())
    
    out_file = output_dir / (json_file.stem + ".parquet")  # .stem -- get the filename without extension
    df.to_parquet(out_file, index=False)

    print(f"{out_file} is created successfully.")
# Out:
# data\parquet\quakes_1990_01.parquet is created successfully.
# data\parquet\quakes_1990_02.parquet is created successfully.
# data\parquet\quakes_1990_03.parquet is created successfully.
# data\parquet\quakes_1990_04.parquet is created successfully.
# data\parquet\quakes_1990_05.parquet is created successfully.
# data\parquet\quakes_1990_06.parquet is created successfully.
# data\parquet\quakes_1990_07.parquet is created successfully.
# data\parquet\quakes_1990_08.parquet is created successfully.
# data\parquet\quakes_1990_09.parquet is created successfully.
# data\parquet\quakes_1990_10.parquet is created successfully.
# data\parquet\quakes_1990_11.parquet is created successfully.
# data\parquet\quakes_1990_12.parquet is created successfully.
# data\parquet\quakes_1991_01.parquet is created successfully.
# data\parquet\quakes_1991_02.parquet is created successfully.
# data\parquet\quakes_1991_03.parquet is created successfully.
# data\parquet\quakes_1991_04.parquet is created successfully.
# data\parquet\quakes_1991_05.parquet is created successfully.
# data\parquet\quakes_1991_06.parquet is created successfully.
# data\parquet\quakes_1991_07.parquet is created successfully.
# data\parquet\quakes_1991_08.parquet is created successfully.
# data\parquet\quakes_1991_09.parquet is created successfully.
# data\parquet\quakes_1991_10.parquet is created successfully.
# data\parquet\quakes_1991_11.parquet is created successfully.
# data\parquet\quakes_1991_12.parquet is created successfully.
# data\parquet\quakes_1992_01.parquet is created successfully.
# data\parquet\quakes_1992_02.parquet is created successfully.
# data\parquet\quakes_1992_03.parquet is created successfully.
# data\parquet\quakes_1992_04.parquet is created successfully.
# data\parquet\quakes_1992_05.parquet is created successfully.
# data\parquet\quakes_1992_06.parquet is created successfully.
# data\parquet\quakes_1992_07.parquet is created successfully.
# data\parquet\quakes_1992_08.parquet is created successfully.
# data\parquet\quakes_1992_09.parquet is created successfully.
# data\parquet\quakes_1992_10.parquet is created successfully.
# data\parquet\quakes_1992_11.parquet is created successfully.
# data\parquet\quakes_1992_12.parquet is created successfully.
# data\parquet\quakes_1993_01.parquet is created successfully.
# data\parquet\quakes_1993_02.parquet is created successfully.
# data\parquet\quakes_1993_03.parquet is created successfully.
# data\parquet\quakes_1993_04.parquet is created successfully.
# data\parquet\quakes_1993_05.parquet is created successfully.
# data\parquet\quakes_1993_06.parquet is created successfully.
# data\parquet\quakes_1993_07.parquet is created successfully.
# data\parquet\quakes_1993_08.parquet is created successfully.
# data\parquet\quakes_1993_09.parquet is created successfully.
# data\parquet\quakes_1993_10.parquet is created successfully.
# data\parquet\quakes_1993_11.parquet is created successfully.
# data\parquet\quakes_1993_12.parquet is created successfully.
# data\parquet\quakes_1994_01.parquet is created successfully.
# data\parquet\quakes_1994_02.parquet is created successfully.
# data\parquet\quakes_1994_03.parquet is created successfully.
# data\parquet\quakes_1994_04.parquet is created successfully.
# data\parquet\quakes_1994_05.parquet is created successfully.
# data\parquet\quakes_1994_06.parquet is created successfully.
# data\parquet\quakes_1994_07.parquet is created successfully.
# data\parquet\quakes_1994_08.parquet is created successfully.
# data\parquet\quakes_1994_09.parquet is created successfully.
# data\parquet\quakes_1994_10.parquet is created successfully.
# data\parquet\quakes_1994_11.parquet is created successfully.
# data\parquet\quakes_1994_12.parquet is created successfully.
# data\parquet\quakes_1995_01.parquet is created successfully.
# data\parquet\quakes_1995_02.parquet is created successfully.
# data\parquet\quakes_1995_03.parquet is created successfully.
# data\parquet\quakes_1995_04.parquet is created successfully.
# data\parquet\quakes_1995_05.parquet is created successfully.
# data\parquet\quakes_1995_06.parquet is created successfully.
# data\parquet\quakes_1995_07.parquet is created successfully.
# data\parquet\quakes_1995_08.parquet is created successfully.
# data\parquet\quakes_1995_09.parquet is created successfully.
# data\parquet\quakes_1995_10.parquet is created successfully.
# data\parquet\quakes_1995_11.parquet is created successfully.
# data\parquet\quakes_1995_12.parquet is created successfully.
# data\parquet\quakes_1996_01.parquet is created successfully.
# data\parquet\quakes_1996_02.parquet is created successfully.
# data\parquet\quakes_1996_03.parquet is created successfully.
# data\parquet\quakes_1996_04.parquet is created successfully.
# data\parquet\quakes_1996_05.parquet is created successfully.
# data\parquet\quakes_1996_06.parquet is created successfully.
# data\parquet\quakes_1996_07.parquet is created successfully.
# data\parquet\quakes_1996_08.parquet is created successfully.
# data\parquet\quakes_1996_09.parquet is created successfully.
# data\parquet\quakes_1996_10.parquet is created successfully.
# data\parquet\quakes_1996_11.parquet is created successfully.
# data\parquet\quakes_1996_12.parquet is created successfully.
# data\parquet\quakes_1997_01.parquet is created successfully.
# data\parquet\quakes_1997_02.parquet is created successfully.
# data\parquet\quakes_1997_03.parquet is created successfully.
# data\parquet\quakes_1997_04.parquet is created successfully.
# data\parquet\quakes_1997_05.parquet is created successfully.
# data\parquet\quakes_1997_06.parquet is created successfully.
# data\parquet\quakes_1997_07.parquet is created successfully.
# data\parquet\quakes_1997_08.parquet is created successfully.
# data\parquet\quakes_1997_09.parquet is created successfully.
# data\parquet\quakes_1997_10.parquet is created successfully.
# data\parquet\quakes_1997_11.parquet is created successfully.
# data\parquet\quakes_1997_12.parquet is created successfully.
# data\parquet\quakes_1998_01.parquet is created successfully.
# data\parquet\quakes_1998_02.parquet is created successfully.
# data\parquet\quakes_1998_03.parquet is created successfully.
# data\parquet\quakes_1998_04.parquet is created successfully.
# data\parquet\quakes_1998_05.parquet is created successfully.
# data\parquet\quakes_1998_06.parquet is created successfully.
# data\parquet\quakes_1998_07.parquet is created successfully.
# data\parquet\quakes_1998_08.parquet is created successfully.
# data\parquet\quakes_1998_09.parquet is created successfully.
# data\parquet\quakes_1998_10.parquet is created successfully.
# data\parquet\quakes_1998_11.parquet is created successfully.
# data\parquet\quakes_1998_12.parquet is created successfully.
# data\parquet\quakes_1999_01.parquet is created successfully.
# data\parquet\quakes_1999_02.parquet is created successfully.
# data\parquet\quakes_1999_03.parquet is created successfully.
# data\parquet\quakes_1999_04.parquet is created successfully.
# data\parquet\quakes_1999_05.parquet is created successfully.
# data\parquet\quakes_1999_06.parquet is created successfully.
# data\parquet\quakes_1999_07.parquet is created successfully.
# data\parquet\quakes_1999_08.parquet is created successfully.
# data\parquet\quakes_1999_09.parquet is created successfully.
# data\parquet\quakes_1999_10.parquet is created successfully.
# data\parquet\quakes_1999_11.parquet is created successfully.
# data\parquet\quakes_1999_12.parquet is created successfully.
# data\parquet\quakes_2000_01.parquet is created successfully.
# data\parquet\quakes_2000_02.parquet is created successfully.
# data\parquet\quakes_2000_03.parquet is created successfully.
# data\parquet\quakes_2000_04.parquet is created successfully.
# data\parquet\quakes_2000_05.parquet is created successfully.
# data\parquet\quakes_2000_06.parquet is created successfully.
# data\parquet\quakes_2000_07.parquet is created successfully.
# data\parquet\quakes_2000_08.parquet is created successfully.
# data\parquet\quakes_2000_09.parquet is created successfully.
# data\parquet\quakes_2000_10.parquet is created successfully.
# data\parquet\quakes_2000_11.parquet is created successfully.
# data\parquet\quakes_2000_12.parquet is created successfully.
# data\parquet\quakes_2001_01.parquet is created successfully.
# data\parquet\quakes_2001_02.parquet is created successfully.
# data\parquet\quakes_2001_03.parquet is created successfully.
# data\parquet\quakes_2001_04.parquet is created successfully.
# data\parquet\quakes_2001_05.parquet is created successfully.
# data\parquet\quakes_2001_06.parquet is created successfully.
# data\parquet\quakes_2001_07.parquet is created successfully.
# data\parquet\quakes_2001_08.parquet is created successfully.
# data\parquet\quakes_2001_09.parquet is created successfully.
# data\parquet\quakes_2001_10.parquet is created successfully.
# data\parquet\quakes_2001_11.parquet is created successfully.
# data\parquet\quakes_2001_12.parquet is created successfully.
# data\parquet\quakes_2002_01.parquet is created successfully.
# data\parquet\quakes_2002_02.parquet is created successfully.
# data\parquet\quakes_2002_03.parquet is created successfully.
# data\parquet\quakes_2002_04.parquet is created successfully.
# data\parquet\quakes_2002_05.parquet is created successfully.
# data\parquet\quakes_2002_06.parquet is created successfully.
# data\parquet\quakes_2002_07.parquet is created successfully.
# data\parquet\quakes_2002_08.parquet is created successfully.
# data\parquet\quakes_2002_09.parquet is created successfully.
# data\parquet\quakes_2002_10.parquet is created successfully.
# data\parquet\quakes_2002_11.parquet is created successfully.
# data\parquet\quakes_2002_12.parquet is created successfully.
# data\parquet\quakes_2003_01.parquet is created successfully.
# data\parquet\quakes_2003_02.parquet is created successfully.
# data\parquet\quakes_2003_03.parquet is created successfully.
# data\parquet\quakes_2003_04.parquet is created successfully.
# data\parquet\quakes_2003_05.parquet is created successfully.
# data\parquet\quakes_2003_06.parquet is created successfully.
# data\parquet\quakes_2003_07.parquet is created successfully.
# data\parquet\quakes_2003_08.parquet is created successfully.
# data\parquet\quakes_2003_09.parquet is created successfully.
# data\parquet\quakes_2003_10.parquet is created successfully.
# data\parquet\quakes_2003_11.parquet is created successfully.
# data\parquet\quakes_2003_12.parquet is created successfully.
# data\parquet\quakes_2004_01.parquet is created successfully.
# data\parquet\quakes_2004_02.parquet is created successfully.
# data\parquet\quakes_2004_03.parquet is created successfully.
# data\parquet\quakes_2004_04.parquet is created successfully.
# data\parquet\quakes_2004_05.parquet is created successfully.
# data\parquet\quakes_2004_06.parquet is created successfully.
# data\parquet\quakes_2004_07.parquet is created successfully.
# data\parquet\quakes_2004_08.parquet is created successfully.
# data\parquet\quakes_2004_09.parquet is created successfully.
# data\parquet\quakes_2004_10.parquet is created successfully.
# data\parquet\quakes_2004_11.parquet is created successfully.
# data\parquet\quakes_2004_12.parquet is created successfully.
# data\parquet\quakes_2005_01.parquet is created successfully.
# data\parquet\quakes_2005_02.parquet is created successfully.
# data\parquet\quakes_2005_03.parquet is created successfully.
# data\parquet\quakes_2005_04.parquet is created successfully.
# data\parquet\quakes_2005_05.parquet is created successfully.
# data\parquet\quakes_2005_06.parquet is created successfully.
# data\parquet\quakes_2005_07.parquet is created successfully.
# data\parquet\quakes_2005_08.parquet is created successfully.
# data\parquet\quakes_2005_09.parquet is created successfully.
# data\parquet\quakes_2005_10.parquet is created successfully.
# data\parquet\quakes_2005_11.parquet is created successfully.
# data\parquet\quakes_2005_12.parquet is created successfully.
# data\parquet\quakes_2006_01.parquet is created successfully.
# data\parquet\quakes_2006_02.parquet is created successfully.
# data\parquet\quakes_2006_03.parquet is created successfully.
# data\parquet\quakes_2006_04.parquet is created successfully.
# data\parquet\quakes_2006_05.parquet is created successfully.
# data\parquet\quakes_2006_06.parquet is created successfully.
# data\parquet\quakes_2006_07.parquet is created successfully.
# data\parquet\quakes_2006_08.parquet is created successfully.
# data\parquet\quakes_2006_09.parquet is created successfully.
# data\parquet\quakes_2006_10.parquet is created successfully.
# data\parquet\quakes_2006_11.parquet is created successfully.
# data\parquet\quakes_2006_12.parquet is created successfully.
# data\parquet\quakes_2007_01.parquet is created successfully.
# data\parquet\quakes_2007_02.parquet is created successfully.
# data\parquet\quakes_2007_03.parquet is created successfully.
# data\parquet\quakes_2007_04.parquet is created successfully.
# data\parquet\quakes_2007_05.parquet is created successfully.
# data\parquet\quakes_2007_06.parquet is created successfully.
# data\parquet\quakes_2007_07.parquet is created successfully.
# data\parquet\quakes_2007_08.parquet is created successfully.
# data\parquet\quakes_2007_09.parquet is created successfully.
# data\parquet\quakes_2007_10.parquet is created successfully.
# data\parquet\quakes_2007_11.parquet is created successfully.
# data\parquet\quakes_2007_12.parquet is created successfully.
# data\parquet\quakes_2008_01.parquet is created successfully.
# data\parquet\quakes_2008_02.parquet is created successfully.
# data\parquet\quakes_2008_03.parquet is created successfully.
# data\parquet\quakes_2008_04.parquet is created successfully.
# data\parquet\quakes_2008_05.parquet is created successfully.
# data\parquet\quakes_2008_06.parquet is created successfully.
# data\parquet\quakes_2008_07.parquet is created successfully.
# data\parquet\quakes_2008_08.parquet is created successfully.
# data\parquet\quakes_2008_09.parquet is created successfully.
# data\parquet\quakes_2008_10.parquet is created successfully.
# data\parquet\quakes_2008_11.parquet is created successfully.
# data\parquet\quakes_2008_12.parquet is created successfully.
# data\parquet\quakes_2009_01.parquet is created successfully.
# data\parquet\quakes_2009_02.parquet is created successfully.
# data\parquet\quakes_2009_03.parquet is created successfully.
# data\parquet\quakes_2009_04.parquet is created successfully.
# data\parquet\quakes_2009_05.parquet is created successfully.
# data\parquet\quakes_2009_06.parquet is created successfully.
# data\parquet\quakes_2009_07.parquet is created successfully.
# data\parquet\quakes_2009_08.parquet is created successfully.
# data\parquet\quakes_2009_09.parquet is created successfully.
# data\parquet\quakes_2009_10.parquet is created successfully.
# data\parquet\quakes_2009_11.parquet is created successfully.
# data\parquet\quakes_2009_12.parquet is created successfully.
# data\parquet\quakes_2010_01.parquet is created successfully.
# data\parquet\quakes_2010_02.parquet is created successfully.
# data\parquet\quakes_2010_03.parquet is created successfully.
# data\parquet\quakes_2010_04.parquet is created successfully.
# data\parquet\quakes_2010_05.parquet is created successfully.
# data\parquet\quakes_2010_06.parquet is created successfully.
# data\parquet\quakes_2010_07.parquet is created successfully.
# data\parquet\quakes_2010_08.parquet is created successfully.
# data\parquet\quakes_2010_09.parquet is created successfully.
# data\parquet\quakes_2010_10.parquet is created successfully.
# data\parquet\quakes_2010_11.parquet is created successfully.
# data\parquet\quakes_2010_12.parquet is created successfully.
# data\parquet\quakes_2011_01.parquet is created successfully.
# data\parquet\quakes_2011_02.parquet is created successfully.
# data\parquet\quakes_2011_03.parquet is created successfully.
# data\parquet\quakes_2011_04.parquet is created successfully.
# data\parquet\quakes_2011_05.parquet is created successfully.
# data\parquet\quakes_2011_06.parquet is created successfully.
# data\parquet\quakes_2011_07.parquet is created successfully.
# data\parquet\quakes_2011_08.parquet is created successfully.
# data\parquet\quakes_2011_09.parquet is created successfully.
# data\parquet\quakes_2011_10.parquet is created successfully.
# data\parquet\quakes_2011_11.parquet is created successfully.
# data\parquet\quakes_2011_12.parquet is created successfully.
# data\parquet\quakes_2012_01.parquet is created successfully.
# data\parquet\quakes_2012_02.parquet is created successfully.
# data\parquet\quakes_2012_03.parquet is created successfully.
# data\parquet\quakes_2012_04.parquet is created successfully.
# data\parquet\quakes_2012_05.parquet is created successfully.
# data\parquet\quakes_2012_06.parquet is created successfully.
# data\parquet\quakes_2012_07.parquet is created successfully.
# data\parquet\quakes_2012_08.parquet is created successfully.
# data\parquet\quakes_2012_09.parquet is created successfully.
# data\parquet\quakes_2012_10.parquet is created successfully.
# data\parquet\quakes_2012_11.parquet is created successfully.
# data\parquet\quakes_2012_12.parquet is created successfully.
# data\parquet\quakes_2013_01.parquet is created successfully.
# data\parquet\quakes_2013_02.parquet is created successfully.
# data\parquet\quakes_2013_03.parquet is created successfully.
# data\parquet\quakes_2013_04.parquet is created successfully.
# data\parquet\quakes_2013_05.parquet is created successfully.
# data\parquet\quakes_2013_06.parquet is created successfully.
# data\parquet\quakes_2013_07.parquet is created successfully.
# data\parquet\quakes_2013_08.parquet is created successfully.
# data\parquet\quakes_2013_09.parquet is created successfully.
# data\parquet\quakes_2013_10.parquet is created successfully.
# data\parquet\quakes_2013_11.parquet is created successfully.
# data\parquet\quakes_2013_12.parquet is created successfully.
# data\parquet\quakes_2014_01.parquet is created successfully.
# data\parquet\quakes_2014_02.parquet is created successfully.
# data\parquet\quakes_2014_03.parquet is created successfully.
# data\parquet\quakes_2014_04.parquet is created successfully.
# data\parquet\quakes_2014_05.parquet is created successfully.
# data\parquet\quakes_2014_06.parquet is created successfully.
# data\parquet\quakes_2014_07.parquet is created successfully.
# data\parquet\quakes_2014_08.parquet is created successfully.
# data\parquet\quakes_2014_09.parquet is created successfully.
# data\parquet\quakes_2014_10.parquet is created successfully.
# data\parquet\quakes_2014_11.parquet is created successfully.
# data\parquet\quakes_2014_12.parquet is created successfully.
# data\parquet\quakes_2015_01.parquet is created successfully.
# data\parquet\quakes_2015_02.parquet is created successfully.
# data\parquet\quakes_2015_03.parquet is created successfully.
# data\parquet\quakes_2015_04.parquet is created successfully.
# data\parquet\quakes_2015_05.parquet is created successfully.
# data\parquet\quakes_2015_06.parquet is created successfully.
# data\parquet\quakes_2015_07.parquet is created successfully.
# data\parquet\quakes_2015_08.parquet is created successfully.
# data\parquet\quakes_2015_09.parquet is created successfully.
# data\parquet\quakes_2015_10.parquet is created successfully.
# data\parquet\quakes_2015_11.parquet is created successfully.
# data\parquet\quakes_2015_12.parquet is created successfully.
# data\parquet\quakes_2016_01.parquet is created successfully.
# data\parquet\quakes_2016_02.parquet is created successfully.
# data\parquet\quakes_2016_03.parquet is created successfully.
# data\parquet\quakes_2016_04.parquet is created successfully.
# data\parquet\quakes_2016_05.parquet is created successfully.
# data\parquet\quakes_2016_06.parquet is created successfully.
# data\parquet\quakes_2016_07.parquet is created successfully.
# data\parquet\quakes_2016_08.parquet is created successfully.
# data\parquet\quakes_2016_09.parquet is created successfully.
# data\parquet\quakes_2016_10.parquet is created successfully.
# data\parquet\quakes_2016_11.parquet is created successfully.
# data\parquet\quakes_2016_12.parquet is created successfully.
# data\parquet\quakes_2017_01.parquet is created successfully.
# data\parquet\quakes_2017_02.parquet is created successfully.
# data\parquet\quakes_2017_03.parquet is created successfully.
# data\parquet\quakes_2017_04.parquet is created successfully.
# data\parquet\quakes_2017_05.parquet is created successfully.
# data\parquet\quakes_2017_06.parquet is created successfully.
# data\parquet\quakes_2017_07.parquet is created successfully.
# data\parquet\quakes_2017_08.parquet is created successfully.
# data\parquet\quakes_2017_09.parquet is created successfully.
# data\parquet\quakes_2017_10.parquet is created successfully.
# data\parquet\quakes_2017_11.parquet is created successfully.
# data\parquet\quakes_2017_12.parquet is created successfully.
# data\parquet\quakes_2018_01.parquet is created successfully.
# data\parquet\quakes_2018_02.parquet is created successfully.
# data\parquet\quakes_2018_03.parquet is created successfully.
# data\parquet\quakes_2018_04.parquet is created successfully.
# data\parquet\quakes_2018_05.parquet is created successfully.
# data\parquet\quakes_2018_06.parquet is created successfully.
# data\parquet\quakes_2018_07.parquet is created successfully.
# data\parquet\quakes_2018_08.parquet is created successfully.
# data\parquet\quakes_2018_09.parquet is created successfully.
# data\parquet\quakes_2018_10.parquet is created successfully.
# data\parquet\quakes_2018_11.parquet is created successfully.
# data\parquet\quakes_2018_12.parquet is created successfully.
# data\parquet\quakes_2019_01.parquet is created successfully.
# data\parquet\quakes_2019_02.parquet is created successfully.
# data\parquet\quakes_2019_03.parquet is created successfully.
# data\parquet\quakes_2019_04.parquet is created successfully.
# data\parquet\quakes_2019_05.parquet is created successfully.
# data\parquet\quakes_2019_06.parquet is created successfully.
# data\parquet\quakes_2019_07.parquet is created successfully.
# data\parquet\quakes_2019_08.parquet is created successfully.
# data\parquet\quakes_2019_09.parquet is created successfully.
# data\parquet\quakes_2019_10.parquet is created successfully.
# data\parquet\quakes_2019_11.parquet is created successfully.
# data\parquet\quakes_2019_12.parquet is created successfully.
# data\parquet\quakes_2020_01.parquet is created successfully.
# data\parquet\quakes_2020_02.parquet is created successfully.
# data\parquet\quakes_2020_03.parquet is created successfully.
# data\parquet\quakes_2020_04.parquet is created successfully.
# data\parquet\quakes_2020_05.parquet is created successfully.
# data\parquet\quakes_2020_06.parquet is created successfully.
# data\parquet\quakes_2020_07.parquet is created successfully.
# data\parquet\quakes_2020_08.parquet is created successfully.
# data\parquet\quakes_2020_09.parquet is created successfully.
# data\parquet\quakes_2020_10.parquet is created successfully.
# data\parquet\quakes_2020_11.parquet is created successfully.
# data\parquet\quakes_2020_12.parquet is created successfully.
# data\parquet\quakes_2021_01.parquet is created successfully.
# data\parquet\quakes_2021_02.parquet is created successfully.
# data\parquet\quakes_2021_03.parquet is created successfully.
# data\parquet\quakes_2021_04.parquet is created successfully.
# data\parquet\quakes_2021_05.parquet is created successfully.
# data\parquet\quakes_2021_06.parquet is created successfully.
# data\parquet\quakes_2021_07.parquet is created successfully.
# data\parquet\quakes_2021_08.parquet is created successfully.
# data\parquet\quakes_2021_09.parquet is created successfully.
# data\parquet\quakes_2021_10.parquet is created successfully.
# data\parquet\quakes_2021_11.parquet is created successfully.
# data\parquet\quakes_2021_12.parquet is created successfully.
# data\parquet\quakes_2022_01.parquet is created successfully.
# data\parquet\quakes_2022_02.parquet is created successfully.
# data\parquet\quakes_2022_03.parquet is created successfully.
# data\parquet\quakes_2022_04.parquet is created successfully.
# data\parquet\quakes_2022_05.parquet is created successfully.
# data\parquet\quakes_2022_06.parquet is created successfully.
# data\parquet\quakes_2022_07.parquet is created successfully.
# data\parquet\quakes_2022_08.parquet is created successfully.
# data\parquet\quakes_2022_09.parquet is created successfully.
# data\parquet\quakes_2022_10.parquet is created successfully.
# data\parquet\quakes_2022_11.parquet is created successfully.
# data\parquet\quakes_2022_12.parquet is created successfully.
# data\parquet\quakes_2023_01.parquet is created successfully.
# data\parquet\quakes_2023_02.parquet is created successfully.
# data\parquet\quakes_2023_03.parquet is created successfully.
# data\parquet\quakes_2023_04.parquet is created successfully.
# data\parquet\quakes_2023_05.parquet is created successfully.
# data\parquet\quakes_2023_06.parquet is created successfully.
# data\parquet\quakes_2023_07.parquet is created successfully.
# data\parquet\quakes_2023_08.parquet is created successfully.
# data\parquet\quakes_2023_09.parquet is created successfully.
# data\parquet\quakes_2023_10.parquet is created successfully.
# data\parquet\quakes_2023_11.parquet is created successfully.
# data\parquet\quakes_2023_12.parquet is created successfully.
# data\parquet\quakes_2024_01.parquet is created successfully.
# data\parquet\quakes_2024_02.parquet is created successfully.
# data\parquet\quakes_2024_03.parquet is created successfully.
# data\parquet\quakes_2024_04.parquet is created successfully.
# data\parquet\quakes_2024_05.parquet is created successfully.
# data\parquet\quakes_2024_06.parquet is created successfully.
# data\parquet\quakes_2024_07.parquet is created successfully.
# data\parquet\quakes_2024_08.parquet is created successfully.
# data\parquet\quakes_2024_09.parquet is created successfully.
# data\parquet\quakes_2024_10.parquet is created successfully.
# data\parquet\quakes_2024_11.parquet is created successfully.
# data\parquet\quakes_2024_12.parquet is created successfully.

# %% [markdown]
# ## Saved in another folder in same bucket
#
# ```bash
# # bash
# cd data/parquet
# mkdir 1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024
# mv quakes_1990_*.parquet 1990
# mv quakes_1991_*.parquet 1991
# mv quakes_1992_*.parquet 1992
# mv quakes_1993_*.parquet 1993
# mv quakes_1994_*.parquet 1994
# mv quakes_1995_*.parquet 1995
# mv quakes_1996_*.parquet 1996
# mv quakes_1997_*.parquet 1997
# mv quakes_1998_*.parquet 1998
# mv quakes_1999_*.parquet 1999
# mv quakes_2000_*.parquet 2000
# mv quakes_2001_*.parquet 2001
# mv quakes_2002_*.parquet 2002
# mv quakes_2003_*.parquet 2003
# mv quakes_2004_*.parquet 2004
# mv quakes_2005_*.parquet 2005
# mv quakes_2006_*.parquet 2006
# mv quakes_2007_*.parquet 2007
# mv quakes_2008_*.parquet 2008
# mv quakes_2009_*.parquet 2009
# mv quakes_2010_*.parquet 2010
# mv quakes_2011_*.parquet 2011
# mv quakes_2012_*.parquet 2012
# mv quakes_2013_*.parquet 2013
# mv quakes_2014_*.parquet 2014
# mv quakes_2015_*.parquet 2015
# mv quakes_2016_*.parquet 2016
# mv quakes_2017_*.parquet 2017
# mv quakes_2018_*.parquet 2018
# mv quakes_2019_*.parquet 2019
# mv quakes_2020_*.parquet 2020
# mv quakes_2021_*.parquet 2021
# mv quakes_2022_*.parquet 2022
# mv quakes_2023_*.parquet 2023
# mv quakes_2024_*.parquet 2024
# ```
# ```powershell
# # powershell
# Set-ExecutionPolicy RemoteSigned
# gcloud auth activate-service-account --key-file=.gcp/key.json   <!-- use your own gcp key file -->
# gcloud config set project your-project-id
# cd ..
# gsutil -m cp -r data/parquet/* gs://your-bucket-name/parquet/
# ```

# %% [markdown]
# ## init database/dataset in bigquery
#
# ```bq CLI
# # bq CLI
# bq mk --location=asia-southeast1 bronze
# bq mk --location=asia-southeast1 silver
# bq mk --location=asia-southeast1 gold
# ```

# %% [markdown]
# ```sql
# # bigquery
# -- Drop old external table
# EXECUTE IMMEDIATE """DROP EXTERNAL TABLE IF EXISTS bronze.usgs_earthquakes""";
#
# -- Create external table
# CREATE OR REPLACE EXTERNAL TABLE bronze.usgs_earthquakes
# OPTIONS (
#     format = 'PARQUET',
#     uris = [
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/1990/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/1991/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/1992/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/1993/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/1994/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/1995/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/1996/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/1997/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/1998/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/1999/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2000/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2001/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2002/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2003/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2004/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2005/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2006/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2007/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2008/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2009/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2010/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2011/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2012/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2013/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2014/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2015/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2016/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2017/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2018/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2019/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2020/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2021/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2022/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2023/*.parquet',
#         'gs://my-free-tier-16-6-usgs-earthquake/parquet/2024/*.parquet'
#     ]
# );
#
# ```

# %% [markdown]
# ## dbt
# ### General Approach for Cleaning (in your .sql model):
# For each column, you'll consider:
#
# 1. **Data Type Conversion (CAST)**: Ensure the data is in the correct type (e.g., STRING, INT64, FLOAT64, TIMESTAMP, BOOLEAN).
#
# 2. **Standardization**:
#
# - Text: TRIM() whitespace, UPPER() or LOWER() for consistency, REPLACE() special characters.
#
# - Numeric: Handle NULLs (e.g., COALESCE(column, 0)), scale units (e.g., convert meters to kilometers if depth is in meters and you want depth_km).
#
# - Dates/Timestamps: Convert to standard UTC timestamps, handle timezones if tz is consistently populated.
#
# 3. **Renaming**: Give columns clear, consistent names (e.g., mag to magnitude, time to event_timestamp_utc). We will do column renaming in gold layer.
#
# 4. **Basic Filtering/Validation**: Simple WHERE clauses for very obvious invalid data (e.g., id IS NOT NULL).
#
# ### General Approach for Testing (in your schema.yml files):
# For each column (or the model as a whole), you'll add tests:
#
# 1. Generic Tests:
#
# - **not_null**: Ensures a column never has NULL values.
#
# - **unique**: Ensures all values in a column are unique (great for IDs).
#
# - **accepted_values**: Ensures values are from a predefined list (e.g., status must be 'reviewed', 'automatic').
#
# - **range**: Checks if numeric values fall within an expected min/max.
#
# - **relationships**: Checks foreign key relationships between models.
#
# 2. Singular Tests: Custom SQL queries to test specific business rules that generic tests can't cover.
